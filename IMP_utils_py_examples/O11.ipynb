# %%
# to install the needed libraries
# %pip install elabapy
# %pip install lxml
# Out:
# Requirement already satisfied: elabapy in /Users/samuelbrinkmann/.local/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: requests in /Users/samuelbrinkmann/.local/lib/python3.10/site-packages (from elabapy) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/samuelbrinkmann/.local/lib/python3.10/site-packages (from requests->elabapy) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/IMP/lib/python3.10/site-packages (from requests->elabapy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/IMP/lib/python3.10/site-packages (from requests->elabapy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuelbrinkmann/.local/lib/python3.10/site-packages (from requests->elabapy) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lxml in /opt/anaconda3/envs/IMP/lib/python3.10/site-packages (4.9.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Wir importieren elabpy und noch einige weitere Libraries
import pandas as pd
import numpy as np
import elabapy
from requests.exceptions import HTTPError

# %% [markdown]
# Mit der folgenden Code-Zelle greifen wir auf elabFTW zu. Hierzu müssen Sie zunächst in elabFTW einen API-key definieren. Diesen können Sie mit folgenden Schritten definieren:
#
# 1. Gehen Sie auf 'User Panel'
#
# 2. Wählen Sie den 'API Keys' Tab
#
# 3. Unter 'Create new key' definieren Sie einen beliebigen Namen für Ihren Key (z.B. 'me') und klicken dann auf 'Generate an API Key'
#
# 4. Wenn Sie 'Generate an API key' gedrückt haben, erscheint eine lange Zeichenfolge. Diese kopieren Sie in der nächsten Zelle anstelle des dort definierten keys für einen Testnutzer.

# %%
# replace with your api key
MY_API_KEY = '28633cd19875774dcba68443ef4c93f4bc6900ff8e928a9ed0648a875be9ad431ee6019d335480c7acef26'
manager = elabapy.Manager(endpoint="https://elabftw.physik.hu-berlin.de/api/v1/", token=MY_API_KEY, verify=False)

# %% [markdown]
# Jetzt, wo die Verbindung zu elabFTW hergestellt wurde, können wir unseren Versuch laden. Die EXPERIMENT_ID ist einfach die Nummer am Ende der URL, die unseren Versuch anzeigt. Für dieses Beispiel war die URL [https://elabftw.physik.hu-berlin.de/experiments.php?mode=view&id=209]

# %%
EXPERIMENT_ID = 209
try:
    experiment = manager.get_experiment(EXPERIMENT_ID) 
# if something goes wrong, the corresponding HTTPError will be raised
except HTTPError as e:
    print(e)

# %%
htmlCode = experiment["body"]
# Die folgende zeile ausführen, um den HTML Code anzeigen zu lassen:
# print(htmlCode)

# %%
df = pd.read_html(htmlCode, match='Parallele Polarisation')
df[0]
# Out:
#                          0                       1                       2  \
# 0   Parallele Polarisation  Parallele Polarisation  Parallele Polarisation
# 1                   αe (°)                  Ur (V)                  αe (°)
# 2                        5                     NaN                    47.5
# 3                      7.5                  0.1067                      50
# 4                       10                  0.1030                    52.5
# 5                     12.5                  0.0992                      55
# 6                       15                  0.0912                    57.5
# 7                     17.5                  0.0856                      60
# 8                       20                  0.0817                    62.5
# 9                     22.5                  0.0790                      65
# 10                      25                  0.0730                    67.5
# 11                    27.5                  0.0685                      70
# 12                      30                  0.0626                    72.5
# 13                    32.5                  0.0545                      75
# 14                      35                  0.0501                    77.5
# 15                    37.5                  0.0420                      80
# 16                      40                  0.0361                    82.5
# 17                    42.5                  0.0296                      85
# 18                      45                  0.0212                     NaN
#
#                          3                        4                        5  \
# 0   Parallele Polarisation  Senkrechte Polarisation  Senkrechte Polarisation
# 1                   Ur (V)                   αe (°)                   Ur (V)
# 2                   0.0158                        5                      NaN
# 3                   0.0088                      7.5                   0.1092
# 4                   0.0042                       10                   0.1109
# 5                        0                     12.5                   0.1181
# 6                   0.0012                       15                   0.1125
# 7                   0.0063                     17.5                   0.1163
# 8                   0.0122                       20                   0.1260
# 9                   0.0365                     22.5                   0.1304
# 10                  0.0831                       25                   0.1374
# 11                  0.1377                     27.5                   0.1421
# 12                  0.2359                       30                   0.1555
# 13                  0.3490                     32.5                   0.1664
# 14                  0.5502                       35                   0.1768
# 15                  0.8494                     37.5                   0.1799
# 16                  1.1453                       40                   0.1932
# 17                  1.3476                     42.5                   0.2212
# 18                     NaN                       45                   0.2479
#
#                           6                        7
# 0   Senkrechte Polarisation  Senkrechte Polarisation
# 1                    αe (°)                   Ur (V)
# 2                      47.5                   0.2752
# 3                        50                   0.3252
# 4                      52.5                   0.3723
# 5                        55                   0.4112
# 6                      57.5                   0.4709
# 7                        60                   0.5300
# 8                      62.5                   0.6138
# 9                        65                   0.7078
# 10                     67.5                   0.8118
# 11                       70                   0.9577
# 12                     72.5                   1.1306
# 13                       75                  1.39000
# 14                     77.5                   1.6331
# 15                       80                   1.9615
# 16                     82.5                   2.1550
# 17                       85                   2.2390
# 18                      NaN                      NaN

# %%
dataTable = df[0].tail(-2).astype('float') # Wir skippen die ersten 2 Zeilen, weil diese den Header enthalten
dataTable
# Out:
#        0       1     2       3     4       5     6       7
# 2    5.0     NaN  47.5  0.0158   5.0     NaN  47.5  0.2752
# 3    7.5  0.1067  50.0  0.0088   7.5  0.1092  50.0  0.3252
# 4   10.0  0.1030  52.5  0.0042  10.0  0.1109  52.5  0.3723
# 5   12.5  0.0992  55.0  0.0000  12.5  0.1181  55.0  0.4112
# 6   15.0  0.0912  57.5  0.0012  15.0  0.1125  57.5  0.4709
# 7   17.5  0.0856  60.0  0.0063  17.5  0.1163  60.0  0.5300
# 8   20.0  0.0817  62.5  0.0122  20.0  0.1260  62.5  0.6138
# 9   22.5  0.0790  65.0  0.0365  22.5  0.1304  65.0  0.7078
# 10  25.0  0.0730  67.5  0.0831  25.0  0.1374  67.5  0.8118
# 11  27.5  0.0685  70.0  0.1377  27.5  0.1421  70.0  0.9577
# 12  30.0  0.0626  72.5  0.2359  30.0  0.1555  72.5  1.1306
# 13  32.5  0.0545  75.0  0.3490  32.5  0.1664  75.0  1.3900
# 14  35.0  0.0501  77.5  0.5502  35.0  0.1768  77.5  1.6331
# 15  37.5  0.0420  80.0  0.8494  37.5  0.1799  80.0  1.9615
# 16  40.0  0.0361  82.5  1.1453  40.0  0.1932  82.5  2.1550
# 17  42.5  0.0296  85.0  1.3476  42.5  0.2212  85.0  2.2390
# 18  45.0  0.0212   NaN     NaN  45.0  0.2479   NaN     NaN

# %%
parallel_degree = list(pd.concat([dataTable[0], dataTable[2]]))
parallel_values = list(pd.concat([dataTable[1], dataTable[3]]))
orth_degree = list(pd.concat([dataTable[4], dataTable[6]]))
orth_values = list(pd.concat([dataTable[5], dataTable[7]]))
df_plot = pd.DataFrame([parallel_degree, parallel_values, orth_degree, orth_values]).transpose()
df_plot.columns = ["a_parallel", "U_parallel", "a_orth", "U_orth"]
df_plot = df_plot[:-1] # drop last row because contains only NaN
df_plot
# Out:
#     a_parallel  U_parallel  a_orth  U_orth
# 0          5.0         NaN     5.0     NaN
# 1          7.5      0.1067     7.5  0.1092
# 2         10.0      0.1030    10.0  0.1109
# 3         12.5      0.0992    12.5  0.1181
# 4         15.0      0.0912    15.0  0.1125
# 5         17.5      0.0856    17.5  0.1163
# 6         20.0      0.0817    20.0  0.1260
# 7         22.5      0.0790    22.5  0.1304
# 8         25.0      0.0730    25.0  0.1374
# 9         27.5      0.0685    27.5  0.1421
# 10        30.0      0.0626    30.0  0.1555
# 11        32.5      0.0545    32.5  0.1664
# 12        35.0      0.0501    35.0  0.1768
# 13        37.5      0.0420    37.5  0.1799
# 14        40.0      0.0361    40.0  0.1932
# 15        42.5      0.0296    42.5  0.2212
# 16        45.0      0.0212    45.0  0.2479
# 17        47.5      0.0158    47.5  0.2752
# 18        50.0      0.0088    50.0  0.3252
# 19        52.5      0.0042    52.5  0.3723
# 20        55.0      0.0000    55.0  0.4112
# 21        57.5      0.0012    57.5  0.4709
# 22        60.0      0.0063    60.0  0.5300
# 23        62.5      0.0122    62.5  0.6138
# 24        65.0      0.0365    65.0  0.7078
# 25        67.5      0.0831    67.5  0.8118
# 26        70.0      0.1377    70.0  0.9577
# 27        72.5      0.2359    72.5  1.1306
# 28        75.0      0.3490    75.0  1.3900
# 29        77.5      0.5502    77.5  1.6331
# 30        80.0      0.8494    80.0  1.9615
# 31        82.5      1.1453    82.5  2.1550
# 32        85.0      1.3476    85.0  2.2390

# %%
# add errors
df_plot["u_a_parallel"] = 0.25
df_plot["u_a_orth"] = 0.25

# formel: 0.03 * U + 0.005
df_plot["u_U_parallel"] = 0.03 * df_plot["U_parallel"] + 0.005
df_plot["u_U_orth"] = 0.03 * df_plot["U_orth"] + 0.005

df_plot
# Out:
#     a_parallel  U_parallel  a_orth  U_orth  u_a_parallel  u_a_orth  \
# 0          5.0         NaN     5.0     NaN          0.25      0.25
# 1          7.5      0.1067     7.5  0.1092          0.25      0.25
# 2         10.0      0.1030    10.0  0.1109          0.25      0.25
# 3         12.5      0.0992    12.5  0.1181          0.25      0.25
# 4         15.0      0.0912    15.0  0.1125          0.25      0.25
# 5         17.5      0.0856    17.5  0.1163          0.25      0.25
# 6         20.0      0.0817    20.0  0.1260          0.25      0.25
# 7         22.5      0.0790    22.5  0.1304          0.25      0.25
# 8         25.0      0.0730    25.0  0.1374          0.25      0.25
# 9         27.5      0.0685    27.5  0.1421          0.25      0.25
# 10        30.0      0.0626    30.0  0.1555          0.25      0.25
# 11        32.5      0.0545    32.5  0.1664          0.25      0.25
# 12        35.0      0.0501    35.0  0.1768          0.25      0.25
# 13        37.5      0.0420    37.5  0.1799          0.25      0.25
# 14        40.0      0.0361    40.0  0.1932          0.25      0.25
# 15        42.5      0.0296    42.5  0.2212          0.25      0.25
# 16        45.0      0.0212    45.0  0.2479          0.25      0.25
# 17        47.5      0.0158    47.5  0.2752          0.25      0.25
# 18        50.0      0.0088    50.0  0.3252          0.25      0.25
# 19        52.5      0.0042    52.5  0.3723          0.25      0.25
# 20        55.0      0.0000    55.0  0.4112          0.25      0.25
# 21        57.5      0.0012    57.5  0.4709          0.25      0.25
# 22        60.0      0.0063    60.0  0.5300          0.25      0.25
# 23        62.5      0.0122    62.5  0.6138          0.25      0.25
# 24        65.0      0.0365    65.0  0.7078          0.25      0.25
# 25        67.5      0.0831    67.5  0.8118          0.25      0.25
# 26        70.0      0.1377    70.0  0.9577          0.25      0.25
# 27        72.5      0.2359    72.5  1.1306          0.25      0.25
# 28        75.0      0.3490    75.0  1.3900          0.25      0.25
# 29        77.5      0.5502    77.5  1.6331          0.25      0.25
# 30        80.0      0.8494    80.0  1.9615          0.25      0.25
# 31        82.5      1.1453    82.5  2.1550          0.25      0.25
# 32        85.0      1.3476    85.0  2.2390          0.25      0.25
#
#     u_U_parallel  u_U_orth
# 0            NaN       NaN
# 1       0.008201  0.008276
# 2       0.008090  0.008327
# 3       0.007976  0.008543
# 4       0.007736  0.008375
# 5       0.007568  0.008489
# 6       0.007451  0.008780
# 7       0.007370  0.008912
# 8       0.007190  0.009122
# 9       0.007055  0.009263
# 10      0.006878  0.009665
# 11      0.006635  0.009992
# 12      0.006503  0.010304
# 13      0.006260  0.010397
# 14      0.006083  0.010796
# 15      0.005888  0.011636
# 16      0.005636  0.012437
# 17      0.005474  0.013256
# 18      0.005264  0.014756
# 19      0.005126  0.016169
# 20      0.005000  0.017336
# 21      0.005036  0.019127
# 22      0.005189  0.020900
# 23      0.005366  0.023414
# 24      0.006095  0.026234
# 25      0.007493  0.029354
# 26      0.009131  0.033731
# 27      0.012077  0.038918
# 28      0.015470  0.046700
# 29      0.021506  0.053993
# 30      0.030482  0.063845
# 31      0.039359  0.069650
# 32      0.045428  0.072170

# %% [markdown]
# **ATTENTION:**
#
# Replace U_REFERENZ_PARALLEL and U_REFERENZ_ORTH with your own reference values

# %%
# R values
U_REFERENZ_PARALLEL = 3.028
U_REFERENZ_ORTH = 3.041

u_U_REFERENZ_PARALLEL = 0.03 * U_REFERENZ_PARALLEL + 0.005
u_U_REFERENZ_ORTH = 0.03 * U_REFERENZ_ORTH + 0.005

df_plot["R_parallel"] = np.sqrt(df_plot["U_parallel"]/U_REFERENZ_PARALLEL)
df_plot["R_orth"] = np.sqrt(df_plot["U_orth"]/U_REFERENZ_ORTH)

# R error values
df_plot["u_R_parallel"] = np.sqrt( (1/2 * 1/np.sqrt(df_plot["U_parallel"]*U_REFERENZ_PARALLEL) * df_plot["u_U_parallel"])**2 + (1/2 * np.sqrt(df_plot["U_parallel"])/U_REFERENZ_PARALLEL**(3/2) * u_U_REFERENZ_PARALLEL)**2)
df_plot["u_R_orth"] = np.sqrt( (1/2 * 1/np.sqrt(df_plot["U_orth"]*U_REFERENZ_ORTH) * df_plot["u_U_orth"])**2 + (1/2 * np.sqrt(df_plot["U_orth"])/U_REFERENZ_ORTH**(3/2) * u_U_REFERENZ_ORTH)**2)

df_plot
# Out:
#     a_parallel  U_parallel  a_orth  U_orth  u_a_parallel  u_a_orth  \
# 0          5.0         NaN     5.0     NaN          0.25      0.25
# 1          7.5      0.1067     7.5  0.1092          0.25      0.25
# 2         10.0      0.1030    10.0  0.1109          0.25      0.25
# 3         12.5      0.0992    12.5  0.1181          0.25      0.25
# 4         15.0      0.0912    15.0  0.1125          0.25      0.25
# 5         17.5      0.0856    17.5  0.1163          0.25      0.25
# 6         20.0      0.0817    20.0  0.1260          0.25      0.25
# 7         22.5      0.0790    22.5  0.1304          0.25      0.25
# 8         25.0      0.0730    25.0  0.1374          0.25      0.25
# 9         27.5      0.0685    27.5  0.1421          0.25      0.25
# 10        30.0      0.0626    30.0  0.1555          0.25      0.25
# 11        32.5      0.0545    32.5  0.1664          0.25      0.25
# 12        35.0      0.0501    35.0  0.1768          0.25      0.25
# 13        37.5      0.0420    37.5  0.1799          0.25      0.25
# 14        40.0      0.0361    40.0  0.1932          0.25      0.25
# 15        42.5      0.0296    42.5  0.2212          0.25      0.25
# 16        45.0      0.0212    45.0  0.2479          0.25      0.25
# 17        47.5      0.0158    47.5  0.2752          0.25      0.25
# 18        50.0      0.0088    50.0  0.3252          0.25      0.25
# 19        52.5      0.0042    52.5  0.3723          0.25      0.25
# 20        55.0      0.0000    55.0  0.4112          0.25      0.25
# 21        57.5      0.0012    57.5  0.4709          0.25      0.25
# 22        60.0      0.0063    60.0  0.5300          0.25      0.25
# 23        62.5      0.0122    62.5  0.6138          0.25      0.25
# 24        65.0      0.0365    65.0  0.7078          0.25      0.25
# 25        67.5      0.0831    67.5  0.8118          0.25      0.25
# 26        70.0      0.1377    70.0  0.9577          0.25      0.25
# 27        72.5      0.2359    72.5  1.1306          0.25      0.25
# 28        75.0      0.3490    75.0  1.3900          0.25      0.25
# 29        77.5      0.5502    77.5  1.6331          0.25      0.25
# 30        80.0      0.8494    80.0  1.9615          0.25      0.25
# 31        82.5      1.1453    82.5  2.1550          0.25      0.25
# 32        85.0      1.3476    85.0  2.2390          0.25      0.25
#
#     u_U_parallel  u_U_orth  R_parallel    R_orth  u_R_parallel  u_R_orth
# 0            NaN       NaN         NaN       NaN           NaN       NaN
# 1       0.008201  0.008276    0.187717  0.189497      0.007802  0.007782
# 2       0.008090  0.008327    0.184434  0.190967      0.007809  0.007780
# 3       0.007976  0.008543    0.181000  0.197068      0.007820  0.007780
# 4       0.007736  0.008375    0.173548  0.192339      0.007856  0.007779
# 5       0.007568  0.008489    0.168135  0.195561      0.007894  0.007779
# 6       0.007451  0.008780    0.164260  0.203553      0.007929  0.007789
# 7       0.007370  0.008912    0.161523  0.207076      0.007956  0.007798
# 8       0.007190  0.009122    0.155269  0.212562      0.008032  0.007817
# 9       0.007055  0.009263    0.150407  0.216167      0.008103  0.007832
# 10      0.006878  0.009665    0.143784  0.226129      0.008220  0.007886
# 11      0.006635  0.009992    0.134159  0.233921      0.008438  0.007939
# 12      0.006503  0.010304    0.128630  0.241120      0.008593  0.007995
# 13      0.006260  0.010397    0.117773  0.243225      0.008973  0.008013
# 14      0.006083  0.010796    0.109188  0.252055      0.009360  0.008093
# 15      0.005888  0.011636    0.098871  0.269702      0.009957  0.008278
# 16      0.005636  0.012437    0.083674  0.285516      0.011201  0.008468
# 17      0.005474  0.013256    0.072235  0.300826      0.012565  0.008669
# 18      0.005264  0.014756    0.053909  0.327015      0.016146  0.009045
# 19      0.005126  0.016169    0.037243  0.349895      0.022735  0.009401
# 20      0.005000  0.017336    0.000000  0.367721           inf  0.009692
# 21      0.005036  0.019127    0.019907  0.393510      0.041773  0.010131
# 22      0.005189  0.020900    0.045613  0.417474      0.018799  0.010554
# 23      0.005366  0.023414    0.063475  0.449268      0.013995  0.011133
# 24      0.006095  0.026234    0.109791  0.482444      0.009330  0.011756
# 25      0.007493  0.029354    0.165662  0.516674      0.007916  0.012413
# 26      0.009131  0.033731    0.213250  0.561186      0.007835  0.013286
# 27      0.012077  0.038918    0.279117  0.609742      0.008400  0.014255
# 28      0.015470  0.046700    0.339496  0.676082      0.009246  0.015602
# 29      0.021506  0.053993    0.426268  0.732821      0.010720  0.016769
# 30      0.030482  0.063845    0.529637  0.803130      0.012672  0.018229
# 31      0.039359  0.069650    0.615009  0.841813      0.014367  0.019039
# 32      0.045428  0.072170    0.667118  0.858062      0.015424  0.019379

# %%
# save as csv
df_plot.to_csv("../data/Grundpraktikum/O11_data.csv")

# %% [markdown]
# ## If some one wants to plot with excel (LOL)

# %%
# save as excel
df_plot.to_excel("O11_data.xlsx", index=False)
